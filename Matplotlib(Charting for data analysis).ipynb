# %% [markdown]
# # What is matplotlib?

# %% [markdown]
# Developer Of Matplotlib Library Is Michael Droettboom And Written By John D.
#  It was conceived by John Hunter in 2002,
# HunterMatplotlib is a cross-platform, data visualization and graphical plotting
# library for Python and its numerical extension NumPy.
# As such, it offers a viable open source alternative to MATLAB.
# Developers can also use matplotlib’s APIs (Application Programming
# Interfaces) to embed plots in GUI applications.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[5,8,17,5])
plt.show()

# %% [markdown]
# # add hadings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[5,8,17,5])
plt.title("Basics data")
plt.xlabel("this is x")
plt.ylabel("this is y")
plt.show()

# %% [markdown]
# # How to plot two line in one plot

# %%
import matplotlib.pyplot as plt
x=[2,4,18]
y=[12,34,56]
x2=[3,10,45]
y2=[7,45,30]
plt.plot(x,y)
plt.plot(x2,y2)
plt.show()

# %% [markdown]
# # How to change plot style

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')    #any other diffretnt style plz check google
x=[2,4,18]
y=[12,34,56]
x2=[3,10,45]
y2=[7,45,30]
plt.plot(x,y)
plt.plot(x2,y2)
plt.show()

# %% [markdown]
# # Labels

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
x=[2,4,18]
y=[12,34,56]
x2=[3,10,45]
y2=[7,45,30]
plt.plot(x,y, label='first')
plt.plot(x2,y2,label='second')
plt.legend()   #first or second is a legand
plt.show()

# %% [markdown]
# # Linewidth

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
x=[2,4,18]
y=[12,34,56]
x2=[3,10,45]
y2=[7,45,30]
plt.plot(x,y, label='first',linewidth=5,c='g')  #change line colour
plt.plot(x2,y2,label='second',linewidth=8)
plt.legend()
plt.show()

# %% [markdown]
# # Scatter plot

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
x=[2,4,18]
y=[12,34,56]
x2=[3,10,45]
y2=[7,45,30]
plt.scatter(x,y, label='first',linewidth=5)
plt.plot(x2,y2,label='second',linewidth=8)
plt.legend()
plt.show()

# %% [markdown]
# # *BarChart

# %%
subject = ['AI','ML','DBMS','SQL']
m1=[5,50,12,14]
m2=[12,14,20,5]
m3=[10,18,30,20]
plt.bar(subject,m1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(subject,m3)
# Out:
# <BarContainer object of 4 artists>

# %%
# ml=50
# dbms = 20
# dbms = 30
# overall sabse jyda classes kon si thi ----> total 3month 
# me max class kon si hai 
# ml==dbms
plt.bar(subject,m1,width=.5,align='center')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,align='edge')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,color='g')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,color='b')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,m2,m3,color = ['green','red','yellow'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject, m1 , color='g')
plt.bar(subject, m2, color='r')
plt.bar (subject, m3,color='y')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Matplotlib-------> methmatical ploting library
#
# # linePlot
# #Histogram
# #Barchart
# #subplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make a graph
no_of_classes = np.array([1,2,3,4,5,6,7])
no_of_students = np.array([4,9,6,4,10,8,6])
plt.plot(no_of_classes,no_of_students)
# plt.show()

# %%
day_of_class = np.array([1,2,3,4,5,6,7])
no_of_students = np.array([4,9,6,4,10,8,6])
plt.plot(day_of_class,no_of_students)
# plt.show()

# %%
no_of_classes = np.array([1,2,3,4,5,6,7])
no_of_students = np.array([4,9,6,4,10,8,6])
plt.plot(no_of_classes,no_of_students,c='g',LineStyle = '-.')
# Out:
# <ipython-input-20-66e96e005f54>:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(no_of_classes,no_of_students,c='g',LineStyle = '-.')

# %%
 day_of_class = np.array([1,2,3,4,5,6,7])
no_of_students = np.array([4,9,6,4,10,8,6])
plt.plot(day_of_class,no_of_students)
plt.xlabel('day_of_class')
plt.ylabel('no_of_students')
plt.title('Attandance')
# Out:
# Text(0.5, 1.0, 'Attandance')

# %% [markdown]
# # Barchart

# %%
#BarChart
subject = ['AI','ML','DBMS','SQL']
m1=[5,50,12,14]
m2=[12,14,20,5]
m3=[10,18,30,20]
plt.bar(subject,m1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(subject,m3)
# Out:
# <BarContainer object of 4 artists>

# %%
# ml=50
# dbms = 20
# dbms = 30
# overall sabse jyda classes kon si thi ----> total 3month 
# me max class kon si hai 
# ml==dbms
plt.bar(subject,m1,width=.5,align='center')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,color='g')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,color='b')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,m2,m3,color = ['green','red','yellow'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject, m1 , color='g')
plt.bar(subject, m2, color='r')
plt.bar (subject, m3,color='y')
# Out:
# <BarContainer object of 4 artists>
