# %% [markdown]
# # what is pandas?

# %% [markdown]
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data",
# and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %% [markdown]
# # What Can Pandas Do?

# %% [markdown]
# Pandas gives you answers about the data. Like:
#
# Is there a correlation between two or more columns?
#
# What is average value?
#
# Max value?
#
# Min value?
#
# Pandas are also able to delete rows that are not relevant,
# or contains wrong values, like empty or NULL values.
# This is called cleaning the data.

# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name":['talim','rohit','aayush','netram','anuj'],
    "marks":[78,56,67,78,89,],
    "city":['punhana','nuh','palwal','balamgarh','farridabad'],
    "Qualification":['BCA','MCA','B-TECH','BBA','MBA'],
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks        city Qualification
# 0   talim     78     punhana           BCA
# 1   rohit     56         nuh           MCA
# 2  aayush     67      palwal        B-TECH
# 3  netram     78   balamgarh           BBA
# 4    anuj     89  farridabad           MBA

# %% [markdown]
# # Export csv file(excel sheet)

# %%
df.to_csv('information.csv')

# %% [markdown]
# # Remov index

# %%
df.to_csv('information_index_false.csv',index=False)

# %%
df.head(3)
# Out:
#      name  marks     city Qualification
# 0   talim     78  punhana           BCA
# 1   rohit     56      nuh           MCA
# 2  aayush     67   palwal        B-TECH

# %%
df.tail(2)
# Out:
#      name  marks        city Qualification
# 3  netram     78   balamgarh           BBA
# 4    anuj     89  farridabad           MBA

# %%
df.describe()         #give numarical calums
# Out:
#           marks
# count   5.00000
# mean   73.60000
# std    12.54193
# min    56.00000
# 25%    67.00000
# 50%    78.00000
# 75%    78.00000
# max    89.00000

# %%
import numpy as np
import pandas as pd

# %%
dict={
    'name':['TALIM','AAYUSH','NETRAM'],
    'city':['Bihar','UP','Punjab'],
    'marks':[22,24,32]
}

# %%
dict
# Out:
# {'name': ['TALIM', 'AAYUSH', 'NETRAM'],
#  'city': ['Bihar', 'UP', 'Punjab'],
#  'marks': [22, 24, 32]}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#      name    city  marks
# 0   TALIM   Bihar     22
# 1  AAYUSH      UP     24
# 2  NETRAM  Punjab     32

# %%
df.to_csv('commondata.csv')

# %%
series = pd.Series(np.random.rand(5))

# %%
series
# Out:
# 0    0.212418
# 1    0.840560
# 2    0.136994
# 3    0.763757
# 4    0.115656
# dtype: float64

# %%
df = pd.DataFrame(np.random.rand(2,5))

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.491556  0.764467  0.301335  0.221683  0.037317
# 1  0.261437  0.779137  0.327666  0.975789  0.015679

# %%
df[0][0]=123

# %%
df
# Out:
#             0         1         2         3         4
# 0  123.000000  0.764467  0.301335  0.221683  0.037317
# 1    0.261437  0.779137  0.327666  0.975789  0.015679

# %%
talim

# %%
talim=['Location'][0]=90

# %%
talim
# Out:
# 90

# %%
s=index = ['second','five','third','four']

# %%
s
# Out:
# ['second', 'five', 'third', 'four']

# %%
s = pd.Series(np.random.rand(5))

# %%
s               #Random value
# Out:
# 0    0.580535
# 1    0.346464
# 2    0.324397
# 3    0.263166
# 4    0.092207
# dtype: float64

# %%
s = pd.DataFrame(np.random.rand(2,5))

# %%
s
# Out:
#           0         1         2         3         4
# 0  0.955395  0.187381  0.781111  0.607134  0.624012
# 1  0.611470  0.693491  0.063769  0.932833  0.560679

# %%
s.isnull().sum()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
df.isnull().value_counts().sum()
# Out:
# 5

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Automobile_data.csv")

# %%
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# # 1. From the given dataset print the first and last five rows

# %%
data.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
data.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
data.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
data.groupby(['price'])

# %%
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# # 5. Count total cars per company

# %%
data.groupby(['company']).size()
# Out:
# company
# alfa-romero      3
# audi             4
# bmw              6
# chevrolet        3
# dodge            2
# honda            3
# isuzu            3
# jaguar           3
# mazda            5
# mercedes-benz    4
# mitsubishi       4
# nissan           5
# porsche          3
# toyota           7
# volkswagen       4
# volvo            2
# dtype: int64

# %% [markdown]
# # 2. Clean the dataset and update the CSV file

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Automobile_data.csv")

# %%
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
data.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
data.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
data.shape
# Out:
# (61, 10)

# %%
data.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   61.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %%
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
data.count()
# Out:
# index               61
# company             61
# body-style          61
# wheel-base          61
# length              61
# engine-type         61
# num-of-cylinders    61
# horsepower          61
# average-mileage     61
# price               58
# dtype: int64

# %%
data.iloc[0:50,1:2]
# Out:
#           company
# 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
# 5            audi
# 6            audi
# 7             bmw
# 8             bmw
# 9             bmw
# 10            bmw
# 11            bmw
# 12            bmw
# 13      chevrolet
# 14      chevrolet
# 15      chevrolet
# 16          dodge
# 17          dodge
# 18          honda
# 19          honda
# 20          honda
# 21          isuzu
# 22          isuzu
# 23          isuzu
# 24         jaguar
# 25         jaguar
# 26         jaguar
# 27          mazda
# 28          mazda
# 29          mazda
# 30          mazda
# 31          mazda
# 32  mercedes-benz
# 33  mercedes-benz
# 34  mercedes-benz
# 35  mercedes-benz
# 36     mitsubishi
# 37     mitsubishi
# 38     mitsubishi
# 39     mitsubishi
# 40         nissan
# 41         nissan
# 42         nissan
# 43         nissan
# 44         nissan
# 45        porsche
# 46        porsche
# 47        porsche
# 48         toyota
# ...

# %%
data.loc[0:50,('company','price')]
# Out:
#           company    price
# 0     alfa-romero  13495.0
# 1     alfa-romero  16500.0
# 2     alfa-romero  16500.0
# 3            audi  13950.0
# 4            audi  17450.0
# 5            audi  15250.0
# 6            audi  18920.0
# 7             bmw  16430.0
# 8             bmw  16925.0
# 9             bmw  20970.0
# 10            bmw  30760.0
# 11            bmw  41315.0
# 12            bmw  36880.0
# 13      chevrolet   5151.0
# 14      chevrolet   6295.0
# 15      chevrolet   6575.0
# 16          dodge   6377.0
# 17          dodge   6229.0
# 18          honda   7295.0
# 19          honda  12945.0
# 20          honda  10345.0
# 21          isuzu   6785.0
# 22          isuzu      NaN
# 23          isuzu      NaN
# 24         jaguar  32250.0
# 25         jaguar  35550.0
# 26         jaguar  36000.0
# 27          mazda   5195.0
# 28          mazda   6095.0
# 29          mazda   6795.0
# 30          mazda  11845.0
# 31          mazda  18344.0
# 32  mercedes-benz  25552.0
# ...

# %%
data.loc[0:50,('company','average-mileage')]
# Out:
#           company  average-mileage
# 0     alfa-romero               21
# 1     alfa-romero               21
# 2     alfa-romero               19
# 3            audi               24
# 4            audi               18
# 5            audi               19
# 6            audi               19
# 7             bmw               23
# 8             bmw               23
# 9             bmw               21
# 10            bmw               16
# 11            bmw               16
# 12            bmw               15
# 13      chevrolet               47
# 14      chevrolet               38
# 15      chevrolet               38
# 16          dodge               31
# 17          dodge               31
# 18          honda               30
# 19          honda               24
# 20          honda               25
# 21          isuzu               24
# 22          isuzu               38
# 23          isuzu               38
# 24         jaguar               15
# 25         jaguar               15
# ...

# %%
data.(['price'])
# Out:
#   File "<ipython-input-73-cb141b7e338a>", line 1
#     data.(['price'])
#          ^
# SyntaxError: invalid syntax
